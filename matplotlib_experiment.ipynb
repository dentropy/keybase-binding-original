# %%
import sqlite_experiment as mah_data
# Out:
# Create sqlite database

# %%
user_list = mah_data.get_list_all_users()
topic_list = mah_data.get_list_all_topics()
characters_per_user = mah_data.get_characters_per_user(user_list)
character_per_topic = mah_data.get_characters_per_topic(topic_list)
messages_per_user = mah_data.get_messages_per_user(user_list)
messages_per_topic = mah_data.get_messages_per_topic(topic_list)
number_users_per_topic = mah_data.get_number_users_per_topic(topic_list)

# %%
import matplotlib.pyplot as plt

# %%
users = [] 
for sublist in characters_per_user:
    users.append(sublist[0])
characters = [] 
for sublist in characters_per_user:
    characters.append(sublist[1])
plt.plot(users,characters)
plt.show()

# %%
users = [] 
for sublist in character_per_topic:
    users.append(sublist[0])
characters = [] 
for sublist in character_per_topic:
    characters.append(sublist[1])
plt.plot(users,characters)
plt.show()

# %%
users = [] 
for sublist in messages_per_user:
    users.append(sublist[0])
characters = [] 
for sublist in messages_per_user:
    characters.append(sublist[1])
plt.plot(users,characters)
plt.show()

# %%
users = [] 
for sublist in messages_per_topic:
    users.append(sublist[0])
characters = [] 
for sublist in messages_per_topic:
    characters.append(sublist[1])
plt.plot(users,characters)
plt.show()

# %%
characters_per_user
# Out:
# [['complexityteam', 44636],
#  ['seebee', 26627],
#  ['drproton', 19271],
#  ['docxology', 18967],
#  ['pmichelu', 15774],
#  ['rj_cordes', 11121],
#  ['davidtalmor', 7083],
#  ['m053m716', 7038],
#  ['dgeaston', 6960],
#  ['jakakistan', 6711],
#  ['dentropy', 6476],
#  ['aswinvk28', 6351],
#  ['taikametsa', 6055],
#  ['jalexcin', 5862],
#  ['jasonlarkin84', 5457],
#  ['murphlf', 4920],
#  ['squasha', 4709],
#  ['mrizz3', 4333],
#  ['scott_david', 4320],
#  ['distantx', 4095],
#  ['eugeneshvarts', 4022],
#  ['ivanmetel', 3605],
#  ['samtdy', 3322],
#  ['depicentre', 3258],
#  ['cobusvanrooyen', 3069],
#  ['baschatel', 2862],
#  ['bleuknight', 2848],
#  ['krisparuch', 2830],
#  ['rose_d', 2777],
#  ['rmaccowan', 2727],
#  ['nivertech', 2529],
#  ['montsekoloffon', 2401],
#  ['steven_ganz', 2396],
#  ['pgmenon', 2334],
#  ['genanasi', 2237],
#  ['jennhuff', 2222],
#  ['kreukle', 2080],
#  ['tuckerc', 1735],
#  ['hectorzenil', 1640],
#  ['mzargham', 1448],
#  ['stephensillett', 1314],
# ...

# %%
character_per_topic
# Out:
# [['flipped-discussion', 47384],
#  ['general', 46100],
#  ['introductions', 38626],
#  ['i-need-a-team', 22534],
#  ['explore-KMS', 17047],
#  ['explore-crowd-meter', 12282],
#  ['explore-complexity', 11109],
#  ['random', 9862],
#  ['explore-ecosystems', 9253],
#  ['explore-sociophysics', 9231],
#  ['flipped-classroom', 8594],
#  ['explore-computation', 8358],
#  ['explore-foodforest', 6810],
#  ['explore-health', 5994],
#  ['tech-support', 5684],
#  ['explore-cities', 4239],
#  ['explore-economics', 3928],
#  ['requests', 3600],
#  ['explore-neuro', 3534],
#  ['explore-art', 3247],
#  ['explore-data-gov', 2551],
#  ['explore-climate', 2177],
#  ['explore-embodiment', 2149],
#  ['explore-entrepreneur', 1624],
#  ['ask-the-facilitators', 1580],
#  ['explore-sensemaking', 1400],
#  ['explore-tech-onboard', 1268],
#  ['explore-agent-based', 1164],
#  ['explore-engineering', 1039],
#  ['explore-complexbooks', 550],
#  ['explore-data-viz', 449],
#  ['explore-governance', 414],
# ...
